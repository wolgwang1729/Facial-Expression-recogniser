# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model=keras.Sequential([
    layers.BatchNormalization(input_shape=[2304]),
    layers.Dense(256,activation='relu'),
    layers.Dropout(0.4),
    layers.BatchNormalization(),
    layers.Dense(512,activation='relu'),
    layers.Dropout(0.4),
    layers.Dense(7,activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=10, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 2304)              9216
#  Normalization)
#
#  dense (Dense)               (None, 256)               590080
#
#  dropout (Dropout)           (None, 256)               0
#
#  batch_normalization_1 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_1 (Dense)             (None, 512)               131584
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 735495 (2.81 MB)
# Trainable params: 730375 (2.79 MB)
# Non-trainable params: 5120 (20.00 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), epochs=100,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 718/718 [==============================] - 12s 14ms/step - loss: 1.8554 - accuracy: 0.2821 - val_loss: 1.6588 - val_accuracy: 0.3366
# Epoch 2/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.6878 - accuracy: 0.3287 - val_loss: 1.6030 - val_accuracy: 0.3725
# Epoch 3/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.6395 - accuracy: 0.3494 - val_loss: 1.5839 - val_accuracy: 0.3744
# Epoch 4/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.6078 - accuracy: 0.3674 - val_loss: 1.5690 - val_accuracy: 0.3934
# Epoch 5/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.5790 - accuracy: 0.3812 - val_loss: 1.5529 - val_accuracy: 0.3922
# Epoch 6/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.5716 - accuracy: 0.3834 - val_loss: 1.5475 - val_accuracy: 0.3950
# Epoch 7/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.5451 - accuracy: 0.3929 - val_loss: 1.5431 - val_accuracy: 0.4020
# Epoch 8/100
# 718/718 [==============================] - 11s 15ms/step - loss: 1.5323 - accuracy: 0.4034 - val_loss: 1.5296 - val_accuracy: 0.4089
# Epoch 9/100
# 718/718 [==============================] - 10s 13ms/step - loss: 1.5121 - accuracy: 0.4087 - val_loss: 1.5107 - val_accuracy: 0.4145
# Epoch 10/100
# 718/718 [==============================] - 11s 16ms/step - loss: 1.5021 - accuracy: 0.4154 - val_loss: 1.5072 - val_accuracy: 0.4162
# Epoch 11/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4923 - accuracy: 0.4182 - val_loss: 1.5028 - val_accuracy: 0.4164
# Epoch 12/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.4741 - accuracy: 0.4252 - val_loss: 1.4946 - val_accuracy: 0.4181
# Epoch 13/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4663 - accuracy: 0.4276 - val_loss: 1.4947 - val_accuracy: 0.4197
# Epoch 14/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.4537 - accuracy: 0.4332 - val_loss: 1.4864 - val_accuracy: 0.4228
# Epoch 15/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.4405 - accuracy: 0.4390 - val_loss: 1.4847 - val_accuracy: 0.4303
# Epoch 16/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4290 - accuracy: 0.4435 - val_loss: 1.4754 - val_accuracy: 0.4289
# Epoch 17/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4273 - accuracy: 0.4442 - val_loss: 1.4826 - val_accuracy: 0.4336
# Epoch 18/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4143 - accuracy: 0.4488 - val_loss: 1.4803 - val_accuracy: 0.4330
# Epoch 19/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4094 - accuracy: 0.4540 - val_loss: 1.4825 - val_accuracy: 0.4232
# Epoch 20/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.3977 - accuracy: 0.4601 - val_loss: 1.4707 - val_accuracy: 0.4343
# Epoch 21/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3917 - accuracy: 0.4603 - val_loss: 1.4676 - val_accuracy: 0.4305
# Epoch 22/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.3844 - accuracy: 0.4602 - val_loss: 1.4657 - val_accuracy: 0.4328
# Epoch 23/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.3707 - accuracy: 0.4681 - val_loss: 1.4568 - val_accuracy: 0.4330
# Epoch 24/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.3650 - accuracy: 0.4674 - val_loss: 1.4661 - val_accuracy: 0.4309
# Epoch 25/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.3630 - accuracy: 0.4706 - val_loss: 1.4631 - val_accuracy: 0.4363
# Epoch 26/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3487 - accuracy: 0.4797 - val_loss: 1.4555 - val_accuracy: 0.4455
# Epoch 27/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3498 - accuracy: 0.4783 - val_loss: 1.4575 - val_accuracy: 0.4420
# Epoch 28/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3375 - accuracy: 0.4837 - val_loss: 1.4526 - val_accuracy: 0.4408
# Epoch 29/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3363 - accuracy: 0.4865 - val_loss: 1.4555 - val_accuracy: 0.4364
# Epoch 30/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3283 - accuracy: 0.4909 - val_loss: 1.4583 - val_accuracy: 0.4356
# Epoch 31/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.3218 - accuracy: 0.4918 - val_loss: 1.4394 - val_accuracy: 0.4410
# Epoch 32/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.3140 - accuracy: 0.4914 - val_loss: 1.4477 - val_accuracy: 0.4495
# Epoch 33/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3046 - accuracy: 0.4997 - val_loss: 1.4582 - val_accuracy: 0.4472
# Epoch 34/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.3058 - accuracy: 0.4942 - val_loss: 1.4429 - val_accuracy: 0.4404
# Epoch 35/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.3015 - accuracy: 0.4992 - val_loss: 1.4598 - val_accuracy: 0.4422
# Epoch 36/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.2953 - accuracy: 0.5005 - val_loss: 1.4431 - val_accuracy: 0.4469
# Epoch 37/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.2755 - accuracy: 0.5103 - val_loss: 1.4344 - val_accuracy: 0.4486
# Epoch 38/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.2793 - accuracy: 0.5072 - val_loss: 1.4463 - val_accuracy: 0.4451
# Epoch 39/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.2700 - accuracy: 0.5131 - val_loss: 1.4405 - val_accuracy: 0.4458
# Epoch 40/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.2714 - accuracy: 0.5094 - val_loss: 1.4505 - val_accuracy: 0.4373
# Epoch 41/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.2762 - accuracy: 0.5103 - val_loss: 1.4457 - val_accuracy: 0.4427
# Epoch 42/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.2673 - accuracy: 0.5132 - val_loss: 1.4482 - val_accuracy: 0.4431
# Epoch 43/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.2519 - accuracy: 0.5185 - val_loss: 1.4496 - val_accuracy: 0.4399
# Epoch 44/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.2526 - accuracy: 0.5151 - val_loss: 1.4363 - val_accuracy: 0.4532
# Epoch 45/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.2535 - accuracy: 0.5164 - val_loss: 1.4449 - val_accuracy: 0.4403
# Epoch 46/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.2407 - accuracy: 0.5240 - val_loss: 1.4387 - val_accuracy: 0.4497
# Epoch 47/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.2426 - accuracy: 0.5228 - val_loss: 1.4394 - val_accuracy: 0.4453
# <Axes: >
