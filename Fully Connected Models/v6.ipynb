# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model=keras.Sequential([
    layers.BatchNormalization(input_shape=[2304]),
    layers.Dense(512,activation='relu'),
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dense(256,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(7,activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=10, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 2304)              9216
#  Normalization)
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout (Dropout)           (None, 512)               0
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1324551 (5.05 MB)
# Trainable params: 1318919 (5.03 MB)
# Non-trainable params: 5632 (22.00 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), epochs=100,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
# Out:
# Epoch 1/100
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 718/718 [==============================] - 17s 21ms/step - loss: 1.9704 - accuracy: 0.2653 - val_loss: 1.6594 - val_accuracy: 0.3544
# Epoch 2/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.7095 - accuracy: 0.3208 - val_loss: 1.6400 - val_accuracy: 0.3558
# Epoch 3/100
# 718/718 [==============================] - 14s 20ms/step - loss: 1.6615 - accuracy: 0.3408 - val_loss: 1.6038 - val_accuracy: 0.3638
# Epoch 4/100
# 718/718 [==============================] - 14s 20ms/step - loss: 1.6384 - accuracy: 0.3515 - val_loss: 1.6074 - val_accuracy: 0.3727
# Epoch 5/100
# 718/718 [==============================] - 14s 20ms/step - loss: 1.6180 - accuracy: 0.3627 - val_loss: 1.5799 - val_accuracy: 0.3798
# Epoch 6/100
# 718/718 [==============================] - 15s 22ms/step - loss: 1.6106 - accuracy: 0.3635 - val_loss: 1.5774 - val_accuracy: 0.3858
# Epoch 7/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.5973 - accuracy: 0.3662 - val_loss: 1.5791 - val_accuracy: 0.3863
# Epoch 8/100
# 718/718 [==============================] - 16s 23ms/step - loss: 1.5826 - accuracy: 0.3747 - val_loss: 1.5729 - val_accuracy: 0.3880
# Epoch 9/100
# 718/718 [==============================] - 17s 23ms/step - loss: 1.5734 - accuracy: 0.3788 - val_loss: 1.5523 - val_accuracy: 0.3899
# Epoch 10/100
# 718/718 [==============================] - 17s 24ms/step - loss: 1.5639 - accuracy: 0.3842 - val_loss: 1.5421 - val_accuracy: 0.3943
# Epoch 11/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.5515 - accuracy: 0.3922 - val_loss: 1.5443 - val_accuracy: 0.3971
# Epoch 12/100
# 718/718 [==============================] - 17s 23ms/step - loss: 1.5450 - accuracy: 0.3893 - val_loss: 1.5267 - val_accuracy: 0.4030
# Epoch 13/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.5344 - accuracy: 0.3992 - val_loss: 1.5287 - val_accuracy: 0.3986
# Epoch 14/100
# 718/718 [==============================] - 17s 23ms/step - loss: 1.5243 - accuracy: 0.4021 - val_loss: 1.5260 - val_accuracy: 0.4091
# Epoch 15/100
# 718/718 [==============================] - 16s 23ms/step - loss: 1.5126 - accuracy: 0.4088 - val_loss: 1.5084 - val_accuracy: 0.4197
# Epoch 16/100
# 718/718 [==============================] - 17s 23ms/step - loss: 1.5093 - accuracy: 0.4076 - val_loss: 1.5183 - val_accuracy: 0.4122
# Epoch 17/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.5054 - accuracy: 0.4114 - val_loss: 1.5162 - val_accuracy: 0.4114
# Epoch 18/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.4943 - accuracy: 0.4130 - val_loss: 1.5085 - val_accuracy: 0.4126
# Epoch 19/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4825 - accuracy: 0.4220 - val_loss: 1.5077 - val_accuracy: 0.4117
# Epoch 20/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4765 - accuracy: 0.4214 - val_loss: 1.5019 - val_accuracy: 0.4129
# Epoch 21/100
# 718/718 [==============================] - 17s 23ms/step - loss: 1.4774 - accuracy: 0.4238 - val_loss: 1.5052 - val_accuracy: 0.4121
# Epoch 22/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.4741 - accuracy: 0.4203 - val_loss: 1.4927 - val_accuracy: 0.4168
# Epoch 23/100
# 718/718 [==============================] - 17s 23ms/step - loss: 1.4649 - accuracy: 0.4270 - val_loss: 1.4994 - val_accuracy: 0.4110
# Epoch 24/100
# 718/718 [==============================] - 16s 23ms/step - loss: 1.4585 - accuracy: 0.4306 - val_loss: 1.5062 - val_accuracy: 0.4119
# Epoch 25/100
# 718/718 [==============================] - 15s 22ms/step - loss: 1.4545 - accuracy: 0.4307 - val_loss: 1.4896 - val_accuracy: 0.4208
# Epoch 26/100
# 718/718 [==============================] - 18s 25ms/step - loss: 1.4521 - accuracy: 0.4306 - val_loss: 1.4878 - val_accuracy: 0.4197
# Epoch 27/100
# 718/718 [==============================] - 17s 24ms/step - loss: 1.4407 - accuracy: 0.4388 - val_loss: 1.4724 - val_accuracy: 0.4258
# Epoch 28/100
# 718/718 [==============================] - 17s 24ms/step - loss: 1.4459 - accuracy: 0.4379 - val_loss: 1.4999 - val_accuracy: 0.4204
# Epoch 29/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.4385 - accuracy: 0.4374 - val_loss: 1.4964 - val_accuracy: 0.4155
# Epoch 30/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.4301 - accuracy: 0.4377 - val_loss: 1.4898 - val_accuracy: 0.4277
# Epoch 31/100
# 718/718 [==============================] - 16s 23ms/step - loss: 1.4312 - accuracy: 0.4404 - val_loss: 1.4888 - val_accuracy: 0.4208
# Epoch 32/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.4258 - accuracy: 0.4435 - val_loss: 1.4736 - val_accuracy: 0.4295
# Epoch 33/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4241 - accuracy: 0.4443 - val_loss: 1.4681 - val_accuracy: 0.4330
# Epoch 34/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4248 - accuracy: 0.4456 - val_loss: 1.4808 - val_accuracy: 0.4276
# Epoch 35/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4164 - accuracy: 0.4466 - val_loss: 1.4692 - val_accuracy: 0.4347
# Epoch 36/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4128 - accuracy: 0.4536 - val_loss: 1.4754 - val_accuracy: 0.4256
# Epoch 37/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4088 - accuracy: 0.4540 - val_loss: 1.4852 - val_accuracy: 0.4295
# Epoch 38/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3981 - accuracy: 0.4539 - val_loss: 1.4774 - val_accuracy: 0.4230
# Epoch 39/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4022 - accuracy: 0.4533 - val_loss: 1.4666 - val_accuracy: 0.4276
# Epoch 40/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3960 - accuracy: 0.4568 - val_loss: 1.4799 - val_accuracy: 0.4202
# Epoch 41/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.4011 - accuracy: 0.4542 - val_loss: 1.4781 - val_accuracy: 0.4284
# Epoch 42/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3889 - accuracy: 0.4607 - val_loss: 1.4650 - val_accuracy: 0.4312
# Epoch 43/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3856 - accuracy: 0.4599 - val_loss: 1.4746 - val_accuracy: 0.4312
# Epoch 44/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3880 - accuracy: 0.4597 - val_loss: 1.4642 - val_accuracy: 0.4343
# Epoch 45/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3856 - accuracy: 0.4580 - val_loss: 1.4710 - val_accuracy: 0.4363
# Epoch 46/100
# 718/718 [==============================] - 16s 23ms/step - loss: 1.3775 - accuracy: 0.4578 - val_loss: 1.4662 - val_accuracy: 0.4321
# Epoch 47/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3746 - accuracy: 0.4624 - val_loss: 1.4683 - val_accuracy: 0.4356
# Epoch 48/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3824 - accuracy: 0.4639 - val_loss: 1.4748 - val_accuracy: 0.4317
# Epoch 49/100
# 718/718 [==============================] - 16s 23ms/step - loss: 1.3637 - accuracy: 0.4687 - val_loss: 1.4754 - val_accuracy: 0.4310
# Epoch 50/100
# 718/718 [==============================] - 15s 22ms/step - loss: 1.3675 - accuracy: 0.4685 - val_loss: 1.4649 - val_accuracy: 0.4387
# Epoch 51/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3596 - accuracy: 0.4715 - val_loss: 1.4562 - val_accuracy: 0.4385
# Epoch 52/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3572 - accuracy: 0.4700 - val_loss: 1.4627 - val_accuracy: 0.4291
# Epoch 53/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3600 - accuracy: 0.4710 - val_loss: 1.4553 - val_accuracy: 0.4375
# Epoch 54/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3559 - accuracy: 0.4695 - val_loss: 1.4508 - val_accuracy: 0.4446
# Epoch 55/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3505 - accuracy: 0.4769 - val_loss: 1.4658 - val_accuracy: 0.4330
# Epoch 56/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3515 - accuracy: 0.4762 - val_loss: 1.4508 - val_accuracy: 0.4429
# Epoch 57/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3502 - accuracy: 0.4766 - val_loss: 1.4585 - val_accuracy: 0.4286
# Epoch 58/100
# 718/718 [==============================] - 15s 21ms/step - loss: 1.3478 - accuracy: 0.4769 - val_loss: 1.4636 - val_accuracy: 0.4356
# Epoch 59/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3493 - accuracy: 0.4789 - val_loss: 1.4613 - val_accuracy: 0.4323
# Epoch 60/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3364 - accuracy: 0.4813 - val_loss: 1.4548 - val_accuracy: 0.4336
# Epoch 61/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3387 - accuracy: 0.4803 - val_loss: 1.4605 - val_accuracy: 0.4288
# Epoch 62/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3382 - accuracy: 0.4818 - val_loss: 1.4543 - val_accuracy: 0.4385
# Epoch 63/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3247 - accuracy: 0.4840 - val_loss: 1.4507 - val_accuracy: 0.4371
# Epoch 64/100
# 718/718 [==============================] - 16s 22ms/step - loss: 1.3276 - accuracy: 0.4846 - val_loss: 1.4540 - val_accuracy: 0.4408
# <Axes: >
