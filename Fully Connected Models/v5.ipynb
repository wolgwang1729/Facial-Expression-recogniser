# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model=keras.Sequential([
    layers.BatchNormalization(input_shape=[2304]),
    layers.Dense(256,activation='relu'),
    layers.Dropout(0.5),
    layers.BatchNormalization(),
    layers.Dense(256,activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(7,activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=10, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_4 (Bat  (None, 2304)              9216
#  chNormalization)
#
#  dense_6 (Dense)             (None, 256)               590080
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  batch_normalization_5 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_7 (Dense)             (None, 256)               65792
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 667911 (2.55 MB)
# Trainable params: 662791 (2.53 MB)
# Non-trainable params: 5120 (20.00 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), epochs=100,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
# Out:
# Epoch 1/100
# 718/718 [==============================] - 11s 12ms/step - loss: 1.9324 - accuracy: 0.2581 - val_loss: 1.6718 - val_accuracy: 0.3450
# Epoch 2/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.7148 - accuracy: 0.3182 - val_loss: 1.6479 - val_accuracy: 0.3668
# Epoch 3/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.6703 - accuracy: 0.3352 - val_loss: 1.6350 - val_accuracy: 0.3680
# Epoch 4/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.6496 - accuracy: 0.3489 - val_loss: 1.6041 - val_accuracy: 0.3729
# Epoch 5/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.6281 - accuracy: 0.3614 - val_loss: 1.5940 - val_accuracy: 0.3844
# Epoch 6/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.6155 - accuracy: 0.3623 - val_loss: 1.5774 - val_accuracy: 0.3885
# Epoch 7/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.6047 - accuracy: 0.3690 - val_loss: 1.5815 - val_accuracy: 0.3871
# Epoch 8/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.5869 - accuracy: 0.3734 - val_loss: 1.5599 - val_accuracy: 0.3856
# Epoch 9/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5801 - accuracy: 0.3771 - val_loss: 1.5449 - val_accuracy: 0.3936
# Epoch 10/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5681 - accuracy: 0.3828 - val_loss: 1.5491 - val_accuracy: 0.3910
# Epoch 11/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5593 - accuracy: 0.3903 - val_loss: 1.5330 - val_accuracy: 0.3950
# Epoch 12/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5530 - accuracy: 0.3896 - val_loss: 1.5439 - val_accuracy: 0.3896
# Epoch 13/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5416 - accuracy: 0.4018 - val_loss: 1.5297 - val_accuracy: 0.4079
# Epoch 14/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.5299 - accuracy: 0.3992 - val_loss: 1.5258 - val_accuracy: 0.4004
# Epoch 15/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.5320 - accuracy: 0.4014 - val_loss: 1.5267 - val_accuracy: 0.4070
# Epoch 16/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.5224 - accuracy: 0.4058 - val_loss: 1.5319 - val_accuracy: 0.3988
# Epoch 17/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.5165 - accuracy: 0.4047 - val_loss: 1.5101 - val_accuracy: 0.4098
# Epoch 18/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5121 - accuracy: 0.4067 - val_loss: 1.5037 - val_accuracy: 0.4103
# Epoch 19/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.5100 - accuracy: 0.4090 - val_loss: 1.5139 - val_accuracy: 0.4143
# Epoch 20/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4957 - accuracy: 0.4105 - val_loss: 1.4987 - val_accuracy: 0.4176
# Epoch 21/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4953 - accuracy: 0.4187 - val_loss: 1.5034 - val_accuracy: 0.4176
# Epoch 22/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4885 - accuracy: 0.4175 - val_loss: 1.5003 - val_accuracy: 0.4152
# Epoch 23/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4881 - accuracy: 0.4171 - val_loss: 1.5019 - val_accuracy: 0.4105
# Epoch 24/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4796 - accuracy: 0.4210 - val_loss: 1.5029 - val_accuracy: 0.4197
# Epoch 25/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4724 - accuracy: 0.4240 - val_loss: 1.5034 - val_accuracy: 0.4133
# Epoch 26/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4691 - accuracy: 0.4263 - val_loss: 1.4978 - val_accuracy: 0.4225
# Epoch 27/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4669 - accuracy: 0.4289 - val_loss: 1.5008 - val_accuracy: 0.4190
# Epoch 28/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4663 - accuracy: 0.4295 - val_loss: 1.5029 - val_accuracy: 0.4108
# Epoch 29/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.4571 - accuracy: 0.4310 - val_loss: 1.4883 - val_accuracy: 0.4195
# Epoch 30/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4571 - accuracy: 0.4344 - val_loss: 1.4994 - val_accuracy: 0.4228
# Epoch 31/100
# 718/718 [==============================] - 8s 11ms/step - loss: 1.4578 - accuracy: 0.4316 - val_loss: 1.4878 - val_accuracy: 0.4246
# Epoch 32/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4453 - accuracy: 0.4375 - val_loss: 1.4792 - val_accuracy: 0.4232
# Epoch 33/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4431 - accuracy: 0.4393 - val_loss: 1.4949 - val_accuracy: 0.4208
# Epoch 34/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.4474 - accuracy: 0.4367 - val_loss: 1.4800 - val_accuracy: 0.4209
# Epoch 35/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.4399 - accuracy: 0.4429 - val_loss: 1.4747 - val_accuracy: 0.4215
# Epoch 36/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4386 - accuracy: 0.4395 - val_loss: 1.4839 - val_accuracy: 0.4216
# Epoch 37/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4325 - accuracy: 0.4433 - val_loss: 1.4841 - val_accuracy: 0.4204
# Epoch 38/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4277 - accuracy: 0.4451 - val_loss: 1.4867 - val_accuracy: 0.4180
# Epoch 39/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.4199 - accuracy: 0.4456 - val_loss: 1.4851 - val_accuracy: 0.4232
# Epoch 40/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.4292 - accuracy: 0.4451 - val_loss: 1.4867 - val_accuracy: 0.4187
# Epoch 41/100
# 718/718 [==============================] - 10s 14ms/step - loss: 1.4209 - accuracy: 0.4495 - val_loss: 1.4730 - val_accuracy: 0.4276
# Epoch 42/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4211 - accuracy: 0.4501 - val_loss: 1.4767 - val_accuracy: 0.4296
# Epoch 43/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4118 - accuracy: 0.4526 - val_loss: 1.4731 - val_accuracy: 0.4249
# Epoch 44/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4168 - accuracy: 0.4486 - val_loss: 1.4796 - val_accuracy: 0.4284
# Epoch 45/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4086 - accuracy: 0.4541 - val_loss: 1.4661 - val_accuracy: 0.4267
# Epoch 46/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4097 - accuracy: 0.4511 - val_loss: 1.4714 - val_accuracy: 0.4323
# Epoch 47/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4113 - accuracy: 0.4516 - val_loss: 1.4749 - val_accuracy: 0.4310
# Epoch 48/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4006 - accuracy: 0.4566 - val_loss: 1.4785 - val_accuracy: 0.4246
# Epoch 49/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4073 - accuracy: 0.4500 - val_loss: 1.4701 - val_accuracy: 0.4357
# Epoch 50/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.4026 - accuracy: 0.4554 - val_loss: 1.4702 - val_accuracy: 0.4255
# Epoch 51/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.3891 - accuracy: 0.4593 - val_loss: 1.4720 - val_accuracy: 0.4289
# Epoch 52/100
# 718/718 [==============================] - 9s 12ms/step - loss: 1.3947 - accuracy: 0.4572 - val_loss: 1.4798 - val_accuracy: 0.4288
# Epoch 53/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.3954 - accuracy: 0.4566 - val_loss: 1.4832 - val_accuracy: 0.4187
# Epoch 54/100
# 718/718 [==============================] - 9s 13ms/step - loss: 1.3990 - accuracy: 0.4555 - val_loss: 1.4707 - val_accuracy: 0.4317
# Epoch 55/100
# 718/718 [==============================] - 8s 12ms/step - loss: 1.3878 - accuracy: 0.4621 - val_loss: 1.4718 - val_accuracy: 0.4293
# <Axes: >
