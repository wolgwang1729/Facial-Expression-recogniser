# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model = keras.Sequential([
    layers.Reshape((48, 48, 1), input_shape=(2304,)),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),

    layers.Flatten(),
    
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    
    layers.Dense(7, activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 48, 48, 1)         0
#
#  batch_normalization (Batch  (None, 48, 48, 1)         4
#  Normalization)
#
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  batch_normalization_1 (Bat  (None, 23, 23, 64)        256
#  chNormalization)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  batch_normalization_2 (Bat  (None, 12800)             51200
#  chNormalization)
#
#  dense (Dense)               (None, 128)               1638528
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 1765387 (6.73 MB)
# Trainable params: 1739657 (6.64 MB)
# Non-trainable params: 25730 (100.51 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), batch_size=128,epochs=50,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
model.save_weights('model_weights.h5')
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 180/180 [==============================] - 86s 448ms/step - loss: 2.2123 - accuracy: 0.2794 - val_loss: 1.9293 - val_accuracy: 0.2778
# Epoch 2/50
# 180/180 [==============================] - 78s 434ms/step - loss: 1.6323 - accuracy: 0.3628 - val_loss: 1.6945 - val_accuracy: 0.3652
# Epoch 3/50
# 180/180 [==============================] - 76s 424ms/step - loss: 1.5357 - accuracy: 0.4041 - val_loss: 1.5228 - val_accuracy: 0.4114
# Epoch 4/50
# 180/180 [==============================] - 88s 489ms/step - loss: 1.4808 - accuracy: 0.4245 - val_loss: 1.5485 - val_accuracy: 0.4159
# Epoch 5/50
# 180/180 [==============================] - 77s 430ms/step - loss: 1.4234 - accuracy: 0.4517 - val_loss: 1.4341 - val_accuracy: 0.4500
# Epoch 6/50
# 180/180 [==============================] - 76s 420ms/step - loss: 1.3831 - accuracy: 0.4636 - val_loss: 1.3605 - val_accuracy: 0.4760
# Epoch 7/50
# 180/180 [==============================] - 76s 425ms/step - loss: 1.3457 - accuracy: 0.4825 - val_loss: 1.3230 - val_accuracy: 0.4862
# Epoch 8/50
# 180/180 [==============================] - 64s 356ms/step - loss: 1.3168 - accuracy: 0.4893 - val_loss: 1.3139 - val_accuracy: 0.4993
# Epoch 9/50
# 180/180 [==============================] - 77s 428ms/step - loss: 1.2875 - accuracy: 0.5008 - val_loss: 1.2774 - val_accuracy: 0.5021
# Epoch 10/50
# 180/180 [==============================] - 77s 426ms/step - loss: 1.2690 - accuracy: 0.5104 - val_loss: 1.2925 - val_accuracy: 0.5038
# Epoch 11/50
# 180/180 [==============================] - 78s 434ms/step - loss: 1.2364 - accuracy: 0.5232 - val_loss: 1.2845 - val_accuracy: 0.5115
# Epoch 12/50
# 180/180 [==============================] - 75s 418ms/step - loss: 1.2217 - accuracy: 0.5259 - val_loss: 1.2590 - val_accuracy: 0.5190
# Epoch 13/50
# 180/180 [==============================] - 76s 420ms/step - loss: 1.1934 - accuracy: 0.5383 - val_loss: 1.2553 - val_accuracy: 0.5225
# Epoch 14/50
# 180/180 [==============================] - 78s 435ms/step - loss: 1.1642 - accuracy: 0.5510 - val_loss: 1.2313 - val_accuracy: 0.5258
# Epoch 15/50
# 180/180 [==============================] - 70s 389ms/step - loss: 1.1524 - accuracy: 0.5535 - val_loss: 1.2275 - val_accuracy: 0.5395
# Epoch 16/50
# 180/180 [==============================] - 69s 384ms/step - loss: 1.1292 - accuracy: 0.5615 - val_loss: 1.2195 - val_accuracy: 0.5411
# Epoch 17/50
# 180/180 [==============================] - 62s 342ms/step - loss: 1.1164 - accuracy: 0.5703 - val_loss: 1.2245 - val_accuracy: 0.5320
# Epoch 18/50
# 180/180 [==============================] - 62s 344ms/step - loss: 1.0989 - accuracy: 0.5816 - val_loss: 1.2120 - val_accuracy: 0.5414
# Epoch 19/50
# 180/180 [==============================] - 60s 333ms/step - loss: 1.0714 - accuracy: 0.5862 - val_loss: 1.2198 - val_accuracy: 0.5441
# Epoch 20/50
# 180/180 [==============================] - 61s 340ms/step - loss: 1.0610 - accuracy: 0.5897 - val_loss: 1.2014 - val_accuracy: 0.5503
# Epoch 21/50
# 180/180 [==============================] - 60s 332ms/step - loss: 1.0390 - accuracy: 0.6032 - val_loss: 1.2161 - val_accuracy: 0.5408
# Epoch 22/50
# 180/180 [==============================] - 63s 348ms/step - loss: 1.0257 - accuracy: 0.6065 - val_loss: 1.2137 - val_accuracy: 0.5467
# Epoch 23/50
# 180/180 [==============================] - 68s 378ms/step - loss: 1.0188 - accuracy: 0.6086 - val_loss: 1.2092 - val_accuracy: 0.5536
# Epoch 24/50
# 180/180 [==============================] - 57s 318ms/step - loss: 0.9915 - accuracy: 0.6161 - val_loss: 1.2005 - val_accuracy: 0.5547
# Epoch 25/50
# 180/180 [==============================] - 57s 319ms/step - loss: 0.9806 - accuracy: 0.6246 - val_loss: 1.1978 - val_accuracy: 0.5594
# Epoch 26/50
# 180/180 [==============================] - 65s 361ms/step - loss: 0.9615 - accuracy: 0.6315 - val_loss: 1.2052 - val_accuracy: 0.5596
# Epoch 27/50
# 180/180 [==============================] - 59s 327ms/step - loss: 0.9549 - accuracy: 0.6350 - val_loss: 1.2141 - val_accuracy: 0.5547
# Epoch 28/50
# 180/180 [==============================] - 56s 312ms/step - loss: 0.9382 - accuracy: 0.6410 - val_loss: 1.2137 - val_accuracy: 0.5500
# Epoch 29/50
# 180/180 [==============================] - 56s 312ms/step - loss: 0.9317 - accuracy: 0.6446 - val_loss: 1.2153 - val_accuracy: 0.5620
# Epoch 30/50
# 180/180 [==============================] - 56s 313ms/step - loss: 0.9261 - accuracy: 0.6435 - val_loss: 1.2079 - val_accuracy: 0.5603
