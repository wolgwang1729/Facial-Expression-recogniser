# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model = keras.Sequential([
    layers.Reshape((48, 48, 1), input_shape=(2304,)),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),

    layers.Flatten(),
    
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(7, activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 48, 48, 1)         0
#
#  batch_normalization (Batch  (None, 48, 48, 1)         4
#  Normalization)
#
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  batch_normalization_1 (Bat  (None, 23, 23, 64)        256
#  chNormalization)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  batch_normalization_2 (Bat  (None, 10, 10, 128)       512
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization_3 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 494219 (1.89 MB)
# Trainable params: 489737 (1.87 MB)
# Non-trainable params: 4482 (17.51 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), batch_size=128,epochs=50,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
model.save_weights('model_weights.h5')
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 180/180 [==============================] - 73s 379ms/step - loss: 2.0620 - accuracy: 0.2563 - val_loss: 1.9236 - val_accuracy: 0.2786
# Epoch 2/50
# 180/180 [==============================] - 63s 348ms/step - loss: 1.6829 - accuracy: 0.3424 - val_loss: 1.6974 - val_accuracy: 0.3420
# Epoch 3/50
# 180/180 [==============================] - 78s 432ms/step - loss: 1.5703 - accuracy: 0.3874 - val_loss: 1.6205 - val_accuracy: 0.3751
# Epoch 4/50
# 180/180 [==============================] - 65s 361ms/step - loss: 1.4960 - accuracy: 0.4233 - val_loss: 1.4509 - val_accuracy: 0.4401
# Epoch 5/50
# 180/180 [==============================] - 68s 378ms/step - loss: 1.4514 - accuracy: 0.4391 - val_loss: 1.3827 - val_accuracy: 0.4673
# Epoch 6/50
# 180/180 [==============================] - 61s 341ms/step - loss: 1.4049 - accuracy: 0.4570 - val_loss: 1.3243 - val_accuracy: 0.4842
# Epoch 7/50
# 180/180 [==============================] - 61s 341ms/step - loss: 1.3690 - accuracy: 0.4734 - val_loss: 1.3086 - val_accuracy: 0.4977
# Epoch 8/50
# 180/180 [==============================] - 63s 349ms/step - loss: 1.3387 - accuracy: 0.4815 - val_loss: 1.2783 - val_accuracy: 0.5118
# Epoch 9/50
# 180/180 [==============================] - 63s 351ms/step - loss: 1.3106 - accuracy: 0.4928 - val_loss: 1.2344 - val_accuracy: 0.5286
# Epoch 10/50
# 180/180 [==============================] - 76s 425ms/step - loss: 1.2851 - accuracy: 0.5104 - val_loss: 1.2315 - val_accuracy: 0.5291
# Epoch 11/50
# 180/180 [==============================] - 67s 373ms/step - loss: 1.2706 - accuracy: 0.5175 - val_loss: 1.2471 - val_accuracy: 0.5240
# Epoch 12/50
# 180/180 [==============================] - 66s 369ms/step - loss: 1.2565 - accuracy: 0.5191 - val_loss: 1.2043 - val_accuracy: 0.5430
# Epoch 13/50
# 180/180 [==============================] - 65s 363ms/step - loss: 1.2286 - accuracy: 0.5262 - val_loss: 1.1996 - val_accuracy: 0.5425
# Epoch 14/50
# 180/180 [==============================] - 65s 363ms/step - loss: 1.2144 - accuracy: 0.5371 - val_loss: 1.1832 - val_accuracy: 0.5428
# Epoch 15/50
# 180/180 [==============================] - 75s 416ms/step - loss: 1.2055 - accuracy: 0.5401 - val_loss: 1.1945 - val_accuracy: 0.5467
# Epoch 16/50
# 180/180 [==============================] - 68s 378ms/step - loss: 1.1882 - accuracy: 0.5475 - val_loss: 1.1794 - val_accuracy: 0.5533
# Epoch 17/50
# 180/180 [==============================] - 66s 365ms/step - loss: 1.1770 - accuracy: 0.5512 - val_loss: 1.1758 - val_accuracy: 0.5576
# Epoch 18/50
# 180/180 [==============================] - 73s 403ms/step - loss: 1.1693 - accuracy: 0.5536 - val_loss: 1.1635 - val_accuracy: 0.5475
# Epoch 19/50
# 180/180 [==============================] - 68s 376ms/step - loss: 1.1623 - accuracy: 0.5554 - val_loss: 1.1462 - val_accuracy: 0.5644
# Epoch 20/50
# 180/180 [==============================] - 73s 404ms/step - loss: 1.1469 - accuracy: 0.5624 - val_loss: 1.1381 - val_accuracy: 0.5664
# Epoch 21/50
# 180/180 [==============================] - 77s 426ms/step - loss: 1.1301 - accuracy: 0.5684 - val_loss: 1.1273 - val_accuracy: 0.5728
# Epoch 22/50
# 180/180 [==============================] - 76s 421ms/step - loss: 1.1223 - accuracy: 0.5716 - val_loss: 1.1323 - val_accuracy: 0.5667
# Epoch 23/50
# 180/180 [==============================] - 70s 391ms/step - loss: 1.1170 - accuracy: 0.5724 - val_loss: 1.1251 - val_accuracy: 0.5724
# Epoch 24/50
# 180/180 [==============================] - 75s 417ms/step - loss: 1.1129 - accuracy: 0.5741 - val_loss: 1.1226 - val_accuracy: 0.5775
# Epoch 25/50
# 180/180 [==============================] - 70s 387ms/step - loss: 1.1075 - accuracy: 0.5762 - val_loss: 1.1317 - val_accuracy: 0.5724
# Epoch 26/50
# 180/180 [==============================] - 70s 387ms/step - loss: 1.1002 - accuracy: 0.5811 - val_loss: 1.1113 - val_accuracy: 0.5838
# Epoch 27/50
# 180/180 [==============================] - 63s 350ms/step - loss: 1.0866 - accuracy: 0.5848 - val_loss: 1.1109 - val_accuracy: 0.5766
# Epoch 28/50
# 180/180 [==============================] - 65s 359ms/step - loss: 1.0795 - accuracy: 0.5889 - val_loss: 1.1117 - val_accuracy: 0.5784
# Epoch 29/50
# 180/180 [==============================] - 61s 340ms/step - loss: 1.0736 - accuracy: 0.5896 - val_loss: 1.0987 - val_accuracy: 0.5812
# Epoch 30/50
# 180/180 [==============================] - 65s 359ms/step - loss: 1.0678 - accuracy: 0.5966 - val_loss: 1.1040 - val_accuracy: 0.5812
# Epoch 31/50
# 180/180 [==============================] - 65s 359ms/step - loss: 1.0613 - accuracy: 0.5950 - val_loss: 1.1177 - val_accuracy: 0.5752
# Epoch 32/50
# 180/180 [==============================] - 65s 359ms/step - loss: 1.0555 - accuracy: 0.5953 - val_loss: 1.0948 - val_accuracy: 0.5897
# Epoch 33/50
# 180/180 [==============================] - 65s 361ms/step - loss: 1.0514 - accuracy: 0.6000 - val_loss: 1.0961 - val_accuracy: 0.5886
# Epoch 34/50
# 180/180 [==============================] - 63s 350ms/step - loss: 1.0427 - accuracy: 0.5982 - val_loss: 1.1098 - val_accuracy: 0.5846
# Epoch 35/50
# 180/180 [==============================] - 68s 380ms/step - loss: 1.0339 - accuracy: 0.6103 - val_loss: 1.0898 - val_accuracy: 0.5892
# Epoch 36/50
# 180/180 [==============================] - 68s 380ms/step - loss: 1.0377 - accuracy: 0.6033 - val_loss: 1.1003 - val_accuracy: 0.5904
# Epoch 37/50
# 180/180 [==============================] - 63s 350ms/step - loss: 1.0357 - accuracy: 0.6073 - val_loss: 1.0897 - val_accuracy: 0.5878
# Epoch 38/50
# 180/180 [==============================] - 61s 340ms/step - loss: 1.0249 - accuracy: 0.6087 - val_loss: 1.0897 - val_accuracy: 0.5900
# Epoch 39/50
# 180/180 [==============================] - 61s 341ms/step - loss: 1.0216 - accuracy: 0.6101 - val_loss: 1.0836 - val_accuracy: 0.5911
# Epoch 40/50
# 180/180 [==============================] - 62s 344ms/step - loss: 1.0139 - accuracy: 0.6152 - val_loss: 1.0795 - val_accuracy: 0.5921
# Epoch 41/50
# 180/180 [==============================] - 61s 341ms/step - loss: 1.0076 - accuracy: 0.6158 - val_loss: 1.0877 - val_accuracy: 0.5932
# Epoch 42/50
# 180/180 [==============================] - 61s 339ms/step - loss: 1.0100 - accuracy: 0.6130 - val_loss: 1.0805 - val_accuracy: 0.5982
# Epoch 43/50
# 180/180 [==============================] - 61s 339ms/step - loss: 0.9965 - accuracy: 0.6201 - val_loss: 1.0812 - val_accuracy: 0.5975
# Epoch 44/50
# 180/180 [==============================] - 61s 340ms/step - loss: 1.0011 - accuracy: 0.6182 - val_loss: 1.0908 - val_accuracy: 0.5918
# Epoch 45/50
# 180/180 [==============================] - 61s 340ms/step - loss: 0.9926 - accuracy: 0.6208 - val_loss: 1.0842 - val_accuracy: 0.5980
