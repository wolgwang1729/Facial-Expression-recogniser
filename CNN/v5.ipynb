# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model = keras.Sequential([
    layers.Reshape((48, 48, 1), input_shape=(2304,)),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),

    layers.Flatten(),
    
    layers.BatchNormalization(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    
    layers.Dense(7, activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 48, 48, 1)         0
#
#  batch_normalization (Batch  (None, 48, 48, 1)         4
#  Normalization)
#
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  batch_normalization_1 (Bat  (None, 23, 23, 64)        256
#  chNormalization)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  batch_normalization_2 (Bat  (None, 12800)             51200
#  chNormalization)
#
#  dense (Dense)               (None, 64)                819264
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 945675 (3.61 MB)
# Trainable params: 919945 (3.51 MB)
# Non-trainable params: 25730 (100.51 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), batch_size=128,epochs=50,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 180/180 [==============================] - 62s 321ms/step - loss: 2.1485 - accuracy: 0.2657 - val_loss: 1.8099 - val_accuracy: 0.2938
# Epoch 2/50
# 180/180 [==============================] - 60s 332ms/step - loss: 1.6837 - accuracy: 0.3400 - val_loss: 1.5971 - val_accuracy: 0.3608
# Epoch 3/50
# 180/180 [==============================] - 60s 333ms/step - loss: 1.6100 - accuracy: 0.3702 - val_loss: 1.5413 - val_accuracy: 0.3986
# Epoch 4/50
# 180/180 [==============================] - 67s 370ms/step - loss: 1.5578 - accuracy: 0.3929 - val_loss: 1.4528 - val_accuracy: 0.4343
# Epoch 5/50
# 180/180 [==============================] - 70s 388ms/step - loss: 1.5086 - accuracy: 0.4095 - val_loss: 1.4413 - val_accuracy: 0.4350
# Epoch 6/50
# 180/180 [==============================] - 66s 367ms/step - loss: 1.4760 - accuracy: 0.4264 - val_loss: 1.4174 - val_accuracy: 0.4568
# Epoch 7/50
# 180/180 [==============================] - 68s 378ms/step - loss: 1.4344 - accuracy: 0.4425 - val_loss: 1.3838 - val_accuracy: 0.4617
# Epoch 8/50
# 180/180 [==============================] - 65s 361ms/step - loss: 1.3967 - accuracy: 0.4601 - val_loss: 1.3454 - val_accuracy: 0.4798
# Epoch 9/50
# 180/180 [==============================] - 62s 346ms/step - loss: 1.3821 - accuracy: 0.4629 - val_loss: 1.3176 - val_accuracy: 0.4901
# Epoch 10/50
# 180/180 [==============================] - 66s 364ms/step - loss: 1.3566 - accuracy: 0.4707 - val_loss: 1.3168 - val_accuracy: 0.4927
# Epoch 11/50
# 180/180 [==============================] - 65s 360ms/step - loss: 1.3301 - accuracy: 0.4814 - val_loss: 1.3148 - val_accuracy: 0.4962
# Epoch 12/50
# 180/180 [==============================] - 64s 353ms/step - loss: 1.3187 - accuracy: 0.4923 - val_loss: 1.2868 - val_accuracy: 0.4976
# Epoch 13/50
# 180/180 [==============================] - 64s 356ms/step - loss: 1.2992 - accuracy: 0.4960 - val_loss: 1.2803 - val_accuracy: 0.5113
# Epoch 14/50
# 180/180 [==============================] - 65s 360ms/step - loss: 1.2764 - accuracy: 0.5049 - val_loss: 1.2726 - val_accuracy: 0.5096
# Epoch 15/50
# 180/180 [==============================] - 63s 349ms/step - loss: 1.2700 - accuracy: 0.5060 - val_loss: 1.2616 - val_accuracy: 0.5152
# Epoch 16/50
# 180/180 [==============================] - 64s 357ms/step - loss: 1.2478 - accuracy: 0.5194 - val_loss: 1.2506 - val_accuracy: 0.5186
# Epoch 17/50
# 180/180 [==============================] - 61s 337ms/step - loss: 1.2287 - accuracy: 0.5216 - val_loss: 1.2517 - val_accuracy: 0.5164
# Epoch 18/50
# 180/180 [==============================] - 68s 377ms/step - loss: 1.2145 - accuracy: 0.5334 - val_loss: 1.2596 - val_accuracy: 0.5169
# Epoch 19/50
# 180/180 [==============================] - 64s 354ms/step - loss: 1.2040 - accuracy: 0.5349 - val_loss: 1.2259 - val_accuracy: 0.5331
# Epoch 20/50
# 180/180 [==============================] - 64s 356ms/step - loss: 1.1955 - accuracy: 0.5371 - val_loss: 1.2328 - val_accuracy: 0.5279
# Epoch 21/50
# 180/180 [==============================] - 62s 345ms/step - loss: 1.1760 - accuracy: 0.5463 - val_loss: 1.2266 - val_accuracy: 0.5312
# Epoch 22/50
# 180/180 [==============================] - 63s 348ms/step - loss: 1.1628 - accuracy: 0.5527 - val_loss: 1.2289 - val_accuracy: 0.5273
# Epoch 23/50
# 180/180 [==============================] - 63s 351ms/step - loss: 1.1611 - accuracy: 0.5489 - val_loss: 1.2185 - val_accuracy: 0.5265
# Epoch 24/50
# 180/180 [==============================] - 63s 351ms/step - loss: 1.1428 - accuracy: 0.5581 - val_loss: 1.2221 - val_accuracy: 0.5350
# Epoch 25/50
# 180/180 [==============================] - 61s 340ms/step - loss: 1.1346 - accuracy: 0.5613 - val_loss: 1.2215 - val_accuracy: 0.5388
# Epoch 26/50
# 180/180 [==============================] - 62s 347ms/step - loss: 1.1287 - accuracy: 0.5658 - val_loss: 1.2174 - val_accuracy: 0.5369
# Epoch 27/50
# 180/180 [==============================] - 61s 338ms/step - loss: 1.1058 - accuracy: 0.5670 - val_loss: 1.2290 - val_accuracy: 0.5320
# Epoch 28/50
# 180/180 [==============================] - 58s 322ms/step - loss: 1.1004 - accuracy: 0.5706 - val_loss: 1.2117 - val_accuracy: 0.5357
# Epoch 29/50
# 180/180 [==============================] - 58s 324ms/step - loss: 1.0832 - accuracy: 0.5793 - val_loss: 1.2208 - val_accuracy: 0.5374
# Epoch 30/50
# 180/180 [==============================] - 63s 348ms/step - loss: 1.0895 - accuracy: 0.5781 - val_loss: 1.2163 - val_accuracy: 0.5392
# Epoch 31/50
# 180/180 [==============================] - 60s 333ms/step - loss: 1.0762 - accuracy: 0.5823 - val_loss: 1.2049 - val_accuracy: 0.5455
# Epoch 32/50
# 180/180 [==============================] - 59s 330ms/step - loss: 1.0778 - accuracy: 0.5841 - val_loss: 1.2100 - val_accuracy: 0.5432
# Epoch 33/50
# 180/180 [==============================] - 62s 346ms/step - loss: 1.0592 - accuracy: 0.5915 - val_loss: 1.1978 - val_accuracy: 0.5502
# Epoch 34/50
# 180/180 [==============================] - 61s 338ms/step - loss: 1.0570 - accuracy: 0.5898 - val_loss: 1.2060 - val_accuracy: 0.5482
# Epoch 35/50
# 180/180 [==============================] - 65s 361ms/step - loss: 1.0428 - accuracy: 0.5935 - val_loss: 1.2088 - val_accuracy: 0.5423
# Epoch 36/50
# 180/180 [==============================] - 62s 345ms/step - loss: 1.0435 - accuracy: 0.5956 - val_loss: 1.1955 - val_accuracy: 0.5498
# Epoch 37/50
# 180/180 [==============================] - 64s 358ms/step - loss: 1.0321 - accuracy: 0.5984 - val_loss: 1.1907 - val_accuracy: 0.5522
# Epoch 38/50
# 180/180 [==============================] - 60s 333ms/step - loss: 1.0296 - accuracy: 0.5998 - val_loss: 1.1846 - val_accuracy: 0.5543
# Epoch 39/50
# 180/180 [==============================] - 57s 317ms/step - loss: 1.0230 - accuracy: 0.6009 - val_loss: 1.1986 - val_accuracy: 0.5543
# Epoch 40/50
# 180/180 [==============================] - 56s 309ms/step - loss: 1.0100 - accuracy: 0.6060 - val_loss: 1.2035 - val_accuracy: 0.5531
# Epoch 41/50
# 180/180 [==============================] - 58s 324ms/step - loss: 1.0114 - accuracy: 0.6055 - val_loss: 1.1944 - val_accuracy: 0.5502
# Epoch 42/50
# 180/180 [==============================] - 56s 313ms/step - loss: 1.0066 - accuracy: 0.6090 - val_loss: 1.1911 - val_accuracy: 0.5550
# Epoch 43/50
# 180/180 [==============================] - 54s 298ms/step - loss: 1.0000 - accuracy: 0.6145 - val_loss: 1.1916 - val_accuracy: 0.5549
# <Axes: >
