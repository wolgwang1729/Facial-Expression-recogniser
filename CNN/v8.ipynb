# %%
import numpy as np 
import pandas as pd

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from keras import layers,callbacks
from keras.utils import to_categorical
import numpy as np
import pandas as pd
train_data=pd.read_csv("train.csv")


X_train, X_val = train_test_split(train_data, test_size=0.2, random_state=18)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
X=X_train.drop("emotions",axis=1)
Y=X_train["emotions"]
X_valid=X_val.drop("emotions",axis=1)
Y_valid=X_val["emotions"]

# %%
model = keras.Sequential([
    layers.Reshape((48, 48, 1), input_shape=(2304,)),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),
    
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.5),

    layers.Flatten(),
    
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    
    layers.Dense(7, activation='linear'),
])

model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],
)
model.summary()


early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=5, # how many epochs to wait before stopping
    restore_best_weights=True,
)
# Out:
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape (Reshape)           (None, 48, 48, 1)         0
#
#  batch_normalization (Batch  (None, 48, 48, 1)         4
#  Normalization)
#
#  conv2d (Conv2D)             (None, 46, 46, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 23, 23, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 23, 23, 64)        0
#
#  batch_normalization_1 (Bat  (None, 23, 23, 64)        256
#  chNormalization)
#
#  conv2d_1 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_1 (MaxPoolin  (None, 10, 10, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 10, 10, 128)       0
#
#  batch_normalization_2 (Bat  (None, 10, 10, 128)       512
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  batch_normalization_3 (Bat  (None, 2048)              8192
#  chNormalization)
#
#  dense (Dense)               (None, 256)               524544
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 757387 (2.89 MB)
# Trainable params: 752905 (2.87 MB)
# Non-trainable params: 4482 (17.51 KB)
# _________________________________________________________________

# %%
history = model.fit(X, Y, validation_data=(X_valid, Y_valid), batch_size=128,epochs=50,callbacks=[early_stopping])
history_df = pd.DataFrame(history.history)
history_df.loc[0:, ['loss', 'val_loss']].plot()
history_df.loc[0:, ['accuracy', 'val_accuracy']].plot()
model.save_weights('model_weights.h5')
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 180/180 [==============================] - 68s 357ms/step - loss: 2.1132 - accuracy: 0.2609 - val_loss: 1.7627 - val_accuracy: 0.2875
# Epoch 2/50
# 180/180 [==============================] - 62s 344ms/step - loss: 1.6866 - accuracy: 0.3478 - val_loss: 1.7401 - val_accuracy: 0.3318
# Epoch 3/50
# 180/180 [==============================] - 64s 358ms/step - loss: 1.5483 - accuracy: 0.4011 - val_loss: 1.5181 - val_accuracy: 0.4305
# Epoch 4/50
# 180/180 [==============================] - 76s 421ms/step - loss: 1.4852 - accuracy: 0.4229 - val_loss: 1.3993 - val_accuracy: 0.4612
# Epoch 5/50
# 180/180 [==============================] - 64s 357ms/step - loss: 1.4353 - accuracy: 0.4402 - val_loss: 1.3982 - val_accuracy: 0.4655
# Epoch 6/50
# 180/180 [==============================] - 69s 386ms/step - loss: 1.3898 - accuracy: 0.4641 - val_loss: 1.3041 - val_accuracy: 0.4991
# Epoch 7/50
# 180/180 [==============================] - 62s 343ms/step - loss: 1.3520 - accuracy: 0.4789 - val_loss: 1.3177 - val_accuracy: 0.4953
# Epoch 8/50
# 180/180 [==============================] - 78s 432ms/step - loss: 1.3217 - accuracy: 0.4931 - val_loss: 1.2568 - val_accuracy: 0.5204
# Epoch 9/50
# 180/180 [==============================] - 63s 351ms/step - loss: 1.2976 - accuracy: 0.4998 - val_loss: 1.2227 - val_accuracy: 0.5352
# Epoch 10/50
# 180/180 [==============================] - 63s 348ms/step - loss: 1.2681 - accuracy: 0.5140 - val_loss: 1.2388 - val_accuracy: 0.5289
# Epoch 11/50
# 180/180 [==============================] - 64s 353ms/step - loss: 1.2432 - accuracy: 0.5274 - val_loss: 1.2073 - val_accuracy: 0.5481
# Epoch 12/50
# 180/180 [==============================] - 71s 396ms/step - loss: 1.2221 - accuracy: 0.5344 - val_loss: 1.1874 - val_accuracy: 0.5552
# Epoch 13/50
# 180/180 [==============================] - 68s 380ms/step - loss: 1.2064 - accuracy: 0.5429 - val_loss: 1.1896 - val_accuracy: 0.5510
# Epoch 14/50
# 180/180 [==============================] - 67s 372ms/step - loss: 1.1892 - accuracy: 0.5467 - val_loss: 1.1694 - val_accuracy: 0.5543
# Epoch 15/50
# 180/180 [==============================] - 68s 380ms/step - loss: 1.1767 - accuracy: 0.5511 - val_loss: 1.1573 - val_accuracy: 0.5543
# Epoch 16/50
# 180/180 [==============================] - 66s 369ms/step - loss: 1.1552 - accuracy: 0.5601 - val_loss: 1.1528 - val_accuracy: 0.5590
# Epoch 17/50
# 180/180 [==============================] - 74s 413ms/step - loss: 1.1402 - accuracy: 0.5663 - val_loss: 1.1422 - val_accuracy: 0.5664
# Epoch 18/50
# 180/180 [==============================] - 78s 434ms/step - loss: 1.1229 - accuracy: 0.5706 - val_loss: 1.1454 - val_accuracy: 0.5677
# Epoch 19/50
# 180/180 [==============================] - 84s 467ms/step - loss: 1.1160 - accuracy: 0.5772 - val_loss: 1.1364 - val_accuracy: 0.5714
# Epoch 20/50
# 180/180 [==============================] - 70s 387ms/step - loss: 1.0943 - accuracy: 0.5856 - val_loss: 1.1243 - val_accuracy: 0.5780
# Epoch 21/50
# 180/180 [==============================] - 62s 346ms/step - loss: 1.0949 - accuracy: 0.5853 - val_loss: 1.1233 - val_accuracy: 0.5759
# Epoch 22/50
# 180/180 [==============================] - 61s 341ms/step - loss: 1.0776 - accuracy: 0.5913 - val_loss: 1.1109 - val_accuracy: 0.5803
# Epoch 23/50
# 180/180 [==============================] - 77s 427ms/step - loss: 1.0653 - accuracy: 0.5916 - val_loss: 1.1079 - val_accuracy: 0.5841
# Epoch 24/50
# 180/180 [==============================] - 71s 395ms/step - loss: 1.0556 - accuracy: 0.5983 - val_loss: 1.0994 - val_accuracy: 0.5866
# Epoch 25/50
# 180/180 [==============================] - 60s 335ms/step - loss: 1.0448 - accuracy: 0.6036 - val_loss: 1.1117 - val_accuracy: 0.5827
# Epoch 26/50
# 180/180 [==============================] - 77s 431ms/step - loss: 1.0402 - accuracy: 0.6048 - val_loss: 1.0943 - val_accuracy: 0.5888
# Epoch 27/50
# 180/180 [==============================] - 80s 444ms/step - loss: 1.0300 - accuracy: 0.6087 - val_loss: 1.0994 - val_accuracy: 0.5895
# Epoch 28/50
# 180/180 [==============================] - 76s 423ms/step - loss: 1.0137 - accuracy: 0.6128 - val_loss: 1.0892 - val_accuracy: 0.5923
# Epoch 29/50
# 180/180 [==============================] - 63s 349ms/step - loss: 1.0124 - accuracy: 0.6173 - val_loss: 1.0884 - val_accuracy: 0.5970
# Epoch 30/50
# 180/180 [==============================] - 58s 324ms/step - loss: 0.9937 - accuracy: 0.6221 - val_loss: 1.0837 - val_accuracy: 0.6015
# Epoch 31/50
# 180/180 [==============================] - 73s 404ms/step - loss: 0.9925 - accuracy: 0.6218 - val_loss: 1.0876 - val_accuracy: 0.5906
# Epoch 32/50
# 180/180 [==============================] - 70s 391ms/step - loss: 0.9817 - accuracy: 0.6293 - val_loss: 1.0805 - val_accuracy: 0.5947
# Epoch 33/50
# 180/180 [==============================] - 58s 323ms/step - loss: 0.9663 - accuracy: 0.6367 - val_loss: 1.0781 - val_accuracy: 0.5996
# Epoch 34/50
# 180/180 [==============================] - 71s 395ms/step - loss: 0.9721 - accuracy: 0.6336 - val_loss: 1.0850 - val_accuracy: 0.5961
# Epoch 35/50
# 180/180 [==============================] - 79s 441ms/step - loss: 0.9524 - accuracy: 0.6409 - val_loss: 1.0881 - val_accuracy: 0.6050
# Epoch 36/50
# 180/180 [==============================] - 79s 442ms/step - loss: 0.9515 - accuracy: 0.6383 - val_loss: 1.0899 - val_accuracy: 0.5930
# Epoch 37/50
# 180/180 [==============================] - 80s 444ms/step - loss: 0.9459 - accuracy: 0.6405 - val_loss: 1.0884 - val_accuracy: 0.5954
# Epoch 38/50
# 180/180 [==============================] - 83s 462ms/step - loss: 0.9411 - accuracy: 0.6471 - val_loss: 1.0770 - val_accuracy: 0.5972
# Epoch 39/50
# 180/180 [==============================] - 73s 403ms/step - loss: 0.9265 - accuracy: 0.6479 - val_loss: 1.0738 - val_accuracy: 0.5989
# Epoch 40/50
# 180/180 [==============================] - 62s 342ms/step - loss: 0.9187 - accuracy: 0.6516 - val_loss: 1.0777 - val_accuracy: 0.5974
# Epoch 41/50
# 180/180 [==============================] - 68s 380ms/step - loss: 0.9175 - accuracy: 0.6537 - val_loss: 1.0795 - val_accuracy: 0.5968
# Epoch 42/50
# 180/180 [==============================] - 61s 341ms/step - loss: 0.9111 - accuracy: 0.6559 - val_loss: 1.0892 - val_accuracy: 0.5940
# Epoch 43/50
# 180/180 [==============================] - 61s 340ms/step - loss: 0.9026 - accuracy: 0.6628 - val_loss: 1.0774 - val_accuracy: 0.6015
# Epoch 44/50
# 180/180 [==============================] - 59s 328ms/step - loss: 0.8946 - accuracy: 0.6629 - val_loss: 1.0706 - val_accuracy: 0.6038
# Epoch 45/50
# 180/180 [==============================] - 61s 338ms/step - loss: 0.8918 - accuracy: 0.6647 - val_loss: 1.0698 - val_accuracy: 0.5993
# Epoch 46/50
# 180/180 [==============================] - 61s 340ms/step - loss: 0.8875 - accuracy: 0.6703 - val_loss: 1.0869 - val_accuracy: 0.6019
# Epoch 47/50
# 180/180 [==============================] - 70s 387ms/step - loss: 0.8869 - accuracy: 0.6643 - val_loss: 1.0799 - val_accuracy: 0.6047
# Epoch 48/50
# 180/180 [==============================] - 5460s 31s/step - loss: 0.8677 - accuracy: 0.6718 - val_loss: 1.0908 - val_accuracy: 0.5968
# Epoch 49/50
# 180/180 [==============================] - 66s 367ms/step - loss: 0.8634 - accuracy: 0.6767 - val_loss: 1.0742 - val_accuracy: 0.6080
